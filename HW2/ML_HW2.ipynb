# %% [markdown]
# <a href="https://colab.research.google.com/github/Reza-aghajari/ML2023/blob/main/AI4021_HW1_2_Python_Tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np

random_int = np.random.randint(1,101,20)
mean = np.mean(random_int)
median = np.median(random_int)
std = np.std(random_int)

print('random integers:', random_int)
print('mean:', mean)
print('median:', median)
print('standard deviation:', std)
# Out:
# random integers: [ 7 43  9 60 67 71 26 45  2 62 88 82 13 44 70 89 98  6 53 30]
# mean: 48.25
# median: 49.0
# standard deviation: 29.866159779924836

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd

data = {
    "Name" : ['Reza', 'asghar', 'mamad', 'jafar', 'rostam'],
    "Age" : [22,11,36,26,41],
    "City" : ['mahshahr', 'tehran', 'kerman', 'ghom', 'toos']
}
df = pd.DataFrame(data)
print('data frame:\n', df)
print('\nfirst 3 rows:\n', df.head(3))
print('\nlast 2 rows:\n', df.tail(2))
print("\nsummary of statics for 'Age' column:\n", df['Age'].describe())
# Out:
# data frame:
#       Name  Age      City
# 0    Reza   22  mahshahr
# 1  asghar   11    tehran
# 2   mamad   36    kerman
# 3   jafar   26      ghom
# 4  rostam   41      toos
#
# first 3 rows:
#       Name  Age      City
# 0    Reza   22  mahshahr
# 1  asghar   11    tehran
# 2   mamad   36    kerman
#
# last 2 rows:
#       Name  Age  City
# 3   jafar   26  ghom
# 4  rostam   41  toos
#
# summary of statics for 'Age' column:
#  count     5.000000
# mean     27.200000
# std      11.819475
# min      11.000000
# 25%      22.000000
# 50%      26.000000
# 75%      36.000000
# max      41.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
import matplotlib.pyplot as plt

months = ['January', 'February', 'March', 'April', 'May']
sales = [10000, 20000, 30000, 15000, 40000]

plt.figure(figsize=(8, 6))
plt.bar(months, sales, color='green')

plt.xlabel('Months')
plt.ylabel('Sales Amount')
plt.title('Monthly Sales for the Store (Jan to May)')

plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np

arr1 = np.random.randint(1,10,(5,5))
arr2 = np.random.randint(1,10,(5,5))
addition = arr1+arr2
subtraction = arr1-arr2
multiplication = arr1*arr2
division = arr1/arr2
print('arr1:\n', arr1)
print('\narr2:\n', arr2)
print('\naddition:\n', addition)
print('\nsubtraction:\n', subtraction)
print('\nmultiplication:\n', multiplication)
print('\ndivision:\n', division)
# Out:
# arr1:
#  [[1 9 6 6 4]
#  [9 4 6 1 9]
#  [8 8 4 8 4]
#  [3 8 5 2 9]
#  [6 1 7 8 1]]
#
# arr2:
#  [[1 6 6 7 6]
#  [4 2 3 1 9]
#  [2 2 1 2 1]
#  [9 7 7 8 9]
#  [7 3 7 3 2]]
#
# addition:
#  [[ 2 15 12 13 10]
#  [13  6  9  2 18]
#  [10 10  5 10  5]
#  [12 15 12 10 18]
#  [13  4 14 11  3]]
#
# subtraction:
#  [[ 0  3  0 -1 -2]
#  [ 5  2  3  0  0]
#  [ 6  6  3  6  3]
#  [-6  1 -2 -6  0]
#  [-1 -2  0  5 -1]]
#
# multiplication:
#  [[ 1 54 36 42 24]
#  [36  8 18  1 81]
#  [16 16  4 16  4]
#  [27 56 35 16 81]
#  [42  3 49 24  2]]
#
# division:
#  [[1.         1.5        1.         0.85714286 0.66666667]
#  [2.25       2.         2.         1.         1.        ]
#  [4.         4.         4.         4.         4.        ]
#  [0.33333333 1.14285714 0.71428571 0.25       1.        ]
#  [0.85714286 0.33333333 1.         2.66666667 0.5       ]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd

data = {
    'Name': ['Reza', 'Asghar', 'mamad', 'jafar', 'rostam'],
    'Age': [46, 25, 57, 20, 25],
    'Position': ['Manager', 'janitor', 'Designer', 'Developer', 'driver']
}

df = pd.DataFrame(data)
filtered_df = df[df['Age'] > 30]

print(filtered_df)
# Out:
#     Name  Age  Position
# 0   Reza   46   Manager
# 2  mamad   57  Designer

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, c='b', marker='o', label='Random Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.title('Scatter Plot of Random Data')

plt.legend()
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np

matrix1 = np.random.rand(2, 3)
matrix2 = np.random.rand(3, 4)
Result = np.dot(matrix1, matrix2)

print('Matrix 1:\n', matrix1)
print('\nMatrix 2:\n', matrix2)
print('\nResult:\n', Result)
# Out:
# Matrix 1:
#  [[0.9495688  0.39552954 0.13213425]
#  [0.79904805 0.70576471 0.05370488]]
#
# Matrix 2:
#  [[0.06985493 0.35869935 0.71187227 0.33424974]
#  [0.93848853 0.131633   0.37509205 0.65064972]
#  [0.0594394  0.8715471  0.74266084 0.70632571]]
#
# Result:
#  [[0.44538598 0.50783567 0.92246261 0.66807413]
#  [0.72136172 0.42632627 0.87343139 0.76422036]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd

data = {
    'Product Category': ['food', 'Groceries', 'Clothings', 'Watch','Clothings','food','food'],
    'Sales Amount': [100, 200, 300, 1500, 1000, 600, 1600]
}

sales_df = pd.DataFrame(data)
category_sales = sales_df.groupby('Product Category')['Sales Amount'].sum().reset_index()
category_sales.rename(columns={'Sales Amount': 'Total Sales'}, inplace=True)
print(category_sales)
# Out:
#   Product Category  Total Sales
# 0        Clothings         1300
# 1        Groceries          200
# 2          Watches         1500
# 3             food         2300

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import matplotlib.pyplot as plt

years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
population = [100000, 120000, 150000, 160000, 165000, 180000, 185000, 190000, 200000, 215000]

plt.figure(figsize=(10, 6))
plt.plot(years, population, marker='o', linestyle='-', color='purple', label='Population Growth')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Growth Over 10 Years')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd

data = {
    'Name': ['Reza', 'Asghar', 'mamad', 'jafar'],
    'Score': [95, 80, 70, 50]
    }
df = pd.DataFrame(data)

def assign_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    else:
        return 'D'

df['Grade'] = df['Score'].apply(assign_grade)

print(df)
# Out:
#      Name  Score Grade
# 0    Reza     95     A
# 1  Asghar     80     B
# 2   mamad     70     C
# 3   jafar     50     D

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)

#1
total_sales = sales_df[['Product A Sales', 'Product B Sales', 'Product C Sales']].sum()
print("Total Sales for Each Product:", total_sales)

#2
average_sales = sales_df[['Product A Sales', 'Product B Sales', 'Product C Sales']].mean()
print("\nAverage Monthly Sales for Each Product:", average_sales)

#3
max_sales_month_A = sales_df[sales_df['Product A Sales'] == sales_df['Product A Sales'].max()]['Month'].values[0]
max_sales_month_B = sales_df[sales_df['Product B Sales'] == sales_df['Product B Sales'].max()]['Month'].values[0]
max_sales_month_C = sales_df[sales_df['Product C Sales'] == sales_df['Product C Sales'].max()]['Month'].values[0]
print("\nMonth with the Highest Sales for Product A:", max_sales_month_A)
print("Month with the Highest Sales for Product B:", max_sales_month_B)
print("Month with the Highest Sales for Product C:", max_sales_month_C)

#4
sales_2022 = sales_df[sales_df['Month'].dt.year == 2022]
percentage_change_A = ((sales_2022['Product A Sales'].iloc[-1] - sales_2022['Product A Sales'].iloc[0]) / sales_2022['Product A Sales'].iloc[0]) * 100
percentage_change_B = ((sales_2022['Product B Sales'].iloc[-1] - sales_2022['Product B Sales'].iloc[0]) / sales_2022['Product B Sales'].iloc[0]) * 100
percentage_change_C = ((sales_2022['Product C Sales'].iloc[-1] - sales_2022['Product C Sales'].iloc[0]) / sales_2022['Product C Sales'].iloc[0]) * 100
print(f"\nPercentage Change in Sales from January to December 2022 for Product A: {percentage_change_A:.2f}%")
print(f"Percentage Change in Sales from January to December 2022 for Product B: {percentage_change_B:.2f}%")
print(f"Percentage Change in Sales from January to December 2022 for Product C: {percentage_change_C:.2f}%")

#5
plt.figure(figsize=(12, 6))
plt.plot(sales_df['Month'], sales_df['Product A Sales'], label='Product A', marker='o')
plt.plot(sales_df['Month'], sales_df['Product B Sales'], label='Product B', marker='o')
plt.plot(sales_df['Month'], sales_df['Product C Sales'], label='Product C', marker='o')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data Over Two Years')
plt.legend()
plt.grid(True)
plt.show()

#6
correlation_AB = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print("\nCorrelation between Product A and Product B Sales:", correlation_AB)
# Out:
# Total Sales for Each Product: Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
#
# Average Monthly Sales for Each Product: Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
#
# Month with the Highest Sales for Product A: 2022-12-31T00:00:00.000000000
# Month with the Highest Sales for Product B: 2022-12-31T00:00:00.000000000
# Month with the Highest Sales for Product C: 2022-12-31T00:00:00.000000000
#
# Percentage Change in Sales from January to December 2022 for Product A: 22.58%
# Percentage Change in Sales from January to December 2022 for Product B: 61.90%
# Percentage Change in Sales from January to December 2022 for Product C: 44.00%
# Correlation between Product A and Product B Sales: 0.954652710589704
